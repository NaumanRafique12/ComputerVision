# %%
#Transfer learning - resnet152V2 .ipynb

# import packages
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

#load model # Accuracy=99.3 , validation Accuracy = 99.3 # heavy model, size =226MB
model_res = load_model('model/resnet152v2_acc_vacc_99_3.h5') #resnet transfer learning

# model accept below hight and width of the image
img_width, img_hight = 224, 224

# %% [markdown]
# # or

# %%
#Own cnn  architecture - mask detection CNN.ipynb

# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

#load model # Accuracy=97.4 , validation Accuracy = 99.1 # very light model, size =5MB
model = load_model('model/model_acc_974_vacc_991.h5') # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200

# %%
# Load the Cascade face Classifier
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#startt  web cam
#cap = cv2.VideoCapture(0) # for webcam
cap = cv2.VideoCapture('videos/Mask - 34775.mp4') # for video

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    responce, color_img = cap.read()
    #color_img = cv2.imread('sandeep.jpg')
    
    #if respoce False the break the loop
    if responce == False:
        break    
    


    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) # 1.1, 3) for 1.mp4
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# user not wearing mask - prob =  0.9992737
# user not wearing mask - prob =  0.99895716
# user not wearing mask - prob =  0.9994079
# user not wearing mask - prob =  0.9992768
# user not wearing mask - prob =  0.9970414
# user not wearing mask - prob =  0.9961094
# user not wearing mask - prob =  0.9927557
# user not wearing mask - prob =  0.9848306
# User with mask - predic =  0.6756902
# user not wearing mask - prob =  0.5310807
# User with mask - predic =  0.94460815
# User with mask - predic =  0.95575964
# User with mask - predic =  0.95491856
# User with mask - predic =  0.98993254
# User with mask - predic =  0.9822013
# User with mask - predic =  0.9705236
# User with mask - predic =  0.98165935
# User with mask - predic =  0.96466744
# User with mask - predic =  0.98790866
# User with mask - predic =  0.98214966
# User with mask - predic =  0.9878999
# User with mask - predic =  0.9772394
# User with mask - predic =  0.97964245
# User with mask - predic =  0.98831207
# User with mask - predic =  0.93666124
# User with mask - predic =  0.803288
# User with mask - predic =  0.6434542
# User with mask - predic =  0.8197615
# User with mask - predic =  0.5090284
# User with mask - predic =  0.8106298
# User with mask - predic =  0.5510392
# User with mask - predic =  0.6269546
# user not wearing mask - prob =  0.52947307
# User with mask - predic =  0.8227331
# User with mask - predic =  0.8820986
# User with mask - predic =  0.94125897
# User with mask - predic =  0.9628673
# User with mask - predic =  0.96548027
# User with mask - predic =  0.9599374
# User with mask - predic =  0.9409377
# User with mask - predic =  0.9377385
# User with mask - predic =  0.78482586
# User with mask - predic =  0.7601743
# User with mask - predic =  0.6799773
# User with mask - predic =  0.77850777
# user not wearing mask - prob =  0.84205234
# User with mask - predic =  0.8078858
# User with mask - predic =  0.7976341
# User with mask - predic =  0.7550429
# User with mask - predic =  0.7776675
# User with mask - predic =  0.7783681
# User with mask - predic =  0.87683153
# User with mask - predic =  0.8092953
# User with mask - predic =  0.8685456
# User with mask - predic =  0.7455266
# User with mask - predic =  0.6849243
# User with mask - predic =  0.7884436
# User with mask - predic =  0.6031912
# User with mask - predic =  0.9519265
# User with mask - predic =  0.95854557
# User with mask - predic =  0.96362954
# User with mask - predic =  0.95829976
# User with mask - predic =  0.96701837
# User with mask - predic =  0.9280363
# User with mask - predic =  0.8602632
# User with mask - predic =  0.84443545
# User with mask - predic =  0.9878428
# User with mask - predic =  0.9986627
# User with mask - predic =  0.9994093
# User with mask - predic =  0.99908483
# User with mask - predic =  0.9991748
# User with mask - predic =  0.99924797
# User with mask - predic =  0.9990225
# User with mask - predic =  0.9994771
# User with mask - predic =  0.9991014
# User with mask - predic =  0.9988403
# User with mask - predic =  0.99933064
# User with mask - predic =  0.9988944
# User with mask - predic =  0.99859506
# User with mask - predic =  0.9990907
# User with mask - predic =  0.9984988
# User with mask - predic =  0.9985719
# User with mask - predic =  0.9993699
# User with mask - predic =  0.9986902
# User with mask - predic =  0.9989662
# User with mask - predic =  0.9986261
# User with mask - predic =  0.9980451
# User with mask - predic =  0.99948907
# User with mask - predic =  0.9995535
# User with mask - predic =  0.99905187
# User with mask - predic =  0.9991014
# User with mask - predic =  0.99952805
# User with mask - predic =  0.99941313
# User with mask - predic =  0.9992483
# User with mask - predic =  0.9995871
# User with mask - predic =  0.99952555
# User with mask - predic =  0.9997539
# User with mask - predic =  0.999395
# User with mask - predic =  0.99950314
# User with mask - predic =  0.9991385
# User with mask - predic =  0.9985936
# User with mask - predic =  0.9990356
# User with mask - predic =  0.9992173
# User with mask - predic =  0.9993507
# User with mask - predic =  0.99900764
# User with mask - predic =  0.9995888
# User with mask - predic =  0.9991091
# User with mask - predic =  0.9994685
# User with mask - predic =  0.9995654
# User with mask - predic =  0.99880517
# User with mask - predic =  0.9996983
# User with mask - predic =  0.9993437
# User with mask - predic =  0.9995159
# User with mask - predic =  0.99983394
